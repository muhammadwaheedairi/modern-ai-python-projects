# %% [markdown]
# # 00_averages

# %%
def average(a: float, b: float) -> float:
    """
    Returns the number which is halfway between a and b.
    """
    return (a + b) / 2

def main():
    avg_1 = average(0, 10)
    avg_2 = average(8, 10)

    final = average(avg_1, avg_2)

    print("avg_1:", avg_1)
    print("avg_2:", avg_2)
    print("final:", final)

if __name__ == '__main__':
    main()

# %% [markdown]
# # 01_chaotic_counting

# %%
import random

DONE_LIKELIHOOD = 0.3  # You can adjust this likelihood

def done():
    """ Returns True with a probability of DONE_LIKELIHOOD """
    return random.random() < DONE_LIKELIHOOD

def chaotic_counting():
    for i in range(1, 11):  # 1 to 10
        if done():
            return  # Stop counting if done() returns True
        print(i)

def main():
    print("I'm going to count until 10 or until I feel like stopping, whichever comes first.")
    chaotic_counting()
    print("I'm done.")

if __name__ == '__main__':
    main()

# %% [markdown]
# # 02_count_even

# %%
def count_even(lst):
    """
    Returns number of even numbers in list.
    >>> count_even([1,2,3,4])
    2
    >>> count_even([1,3,5,7])
    0
    """
    count = 0  # Stores the count of even numbers in the list
    for num in lst:  # Loop through the numbers in the list
        if num % 2 == 0:  # If the current number in the list is even (divisible by 2)
            count += 1  # Add one to our count!

    print(count)  # Print out how many even numbers we counted above

def get_list_of_ints():
    """
    Reads in integers until the user presses enter and returns the resulting list.
    """
    lst = []  # Make an empty list to store integers
    user_input = input("Enter an integer or press enter to stop: ")  # Get user input for an integer
    while user_input != "":  # While the user doesn't enter nothing...
        lst.append(int(user_input))  # Cast the user input into an integer and add it to our list
        user_input = input("Enter an integer or press enter to stop: ")  # Get the next user input

    return lst

def main():
    lst = get_list_of_ints()  # Get the list of integers from the user
    count_even(lst)  # Call the count_even function to print the count of even numbers


if __name__ == '__main__':
    main()

# %% [markdown]
# # 04_double

# %%
def double(num: int):
    return num * 2  # Returns the number multiplied by 2

def main():
    num = int(input("Enter a number: "))  # Prompts the user for a number and converts it to an integer
    num_times_2 = double(num)  # Calls the double function with the user's input
    print("Double that is", num_times_2)  # Prints the doubled value

if __name__ == '__main__':
    main()  # Calls the main function to start the program

# %% [markdown]
# # 05_get_name

# %%
def get_name():
    return "Sophia"  # Returns the string "Sophia"

def main():
    name = get_name()  # Calls the get_name function and stores the returned name in the 'name' variable
    print("Howdy", name, "! 🤠")  # Prints the greeting with the name

if __name__ == '__main__':
    main()  # Calls the main function to run the program

# %% [markdown]
# # 06_is_odd

# %%
def main():
    for i in range(10, 20):  # Change the range to start from 10 to 19
        if is_odd(i):
            print(f"{i} odd")
        else:
            print(f"{i} even")

def is_odd(value: int):
    """
    Checks to see if a value is odd. If it is, returns True.
    """
    remainder = value % 2  # 0 if value is divisible by 2, 1 if it isn't
    return remainder == 1

# There is no need to edit code beyond this point

if __name__ == '__main__':
    main()

# %% [markdown]
# # 07_print_divisor

# %%
def print_divisors(num: int):
    print(f"Here are the divisors of {num}:")
    for i in range(1, num + 1):  # Loop from 1 to num (inclusive)
        if num % i == 0:  # Check if i is a divisor of num
            print(i)

def main():
    num = int(input("Enter a number: "))  # Prompt the user for input
    print_divisors(num)  # Call the print_divisors function with the input number

if __name__ == '__main__':
    main()

# %% [markdown]
# # 08_print_multiple

# %%
def print_multiple(message: str, repeats: int):
    # Loop through the range from 0 to repeats-1
    for i in range(repeats):
        print(message)  # Print the message on each iteration

def main():
    # Get the message and number of repeats from the user
    message = input("Please type a message: ")
    repeats = int(input("Enter a number of times to repeat your message: "))

    # Call the print_multiple function to print the message the required number of times
    print_multiple(message, repeats)

if __name__ == '__main__':
    main()

# %% [markdown]
# # 09_sentence_generator

# %%
def make_sentence(word, part_of_speech):
    if part_of_speech == 0:
        print("I am excited to add this " + word + " to my vast collection of them!")
    elif part_of_speech == 1:
        print("It's so nice outside today it makes me want to " + word + "!")
    elif part_of_speech == 2:
        print("Looking out my window, the sky is big and " + word + "!")
    else:
        print("Part of speech must be 0, 1, or 2! Can't make a sentence.")

def main():
    word = input("Please type a noun, verb, or adjective: ")
    print("Is this a noun, verb, or adjective?")
    part_of_speech = int(input("Type 0 for noun, 1 for verb, 2 for adjective: "))
    make_sentence(word, part_of_speech)

if __name__ == '__main__':
    main()

# %% [markdown]
# # 10_print_ones_digit

# %%
def print_ones_digit(num):
    print("The ones digit is", num % 10)

def main():
    num = int(input("Enter a number: "))
    print_ones_digit(num)

if __name__ == '__main__':
    main()
